# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('IMG_6504.JPG')
rows,cols,ch = img.shape
pts1 = np.float32([[170,193],[760,196],[807,1089],[103,1078]])
pts2 = np.float32([[100,100],[600,100],[600,800],[100,800]])
M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(700,900))
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %%
img = cv2.imread('dsu3.jpg')
rows,cols,ch = img.shape
pts1 = np.float32([[107,226],[700,163],[703,535],[111,496]])
pts2 = np.float32([[100,100],[800,100],[800,600],[100,600]])
M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(900,700))
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()
